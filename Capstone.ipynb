# %% [markdown]
# <a href="https://colab.research.google.com/github/Suba-XIV/Capstone-Project/blob/main/Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ST1 ASSIGNMENT 9**
# # **CAPSTONE PROGRAMMING PROJECT**
# # **MOBILE** **PRICE** **PREDICTION**
# ### **u3238947**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Capstone_Project_ST1/
# Out:
# /content/drive/MyDrive/Capstone_Project_ST1

# %%
# !ls
# Out:
# Cellphone.csv

# %% [markdown]
# # This capstone Project is based on the Mobile Price Prediction. The data is available from the Kaggle repository: (https://www.kaggle.com/datasets/mohannapd/mobile-price-prediction)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
import pandas as pd
import numpy as np
CellphoneData=pd.read_csv('/content/drive/MyDrive/Capstone_Project_ST1/Cellphone.csv', encoding='latin')
print('Shape before deleting duplicate values:', CellphoneData.shape)

# Removing duplicate rows if any
CellphoneData=CellphoneData.drop_duplicates()
print('Shape After deleting duplicate values:', CellphoneData.shape)

# Printing sample data
# Start observing the Quantitative/Categorical/Qualitative variables
CellphoneData.head(10)
# Out:
# Shape before deleting duplicate values: (161, 14)
# Shape After deleting duplicate values: (161, 14)
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
# 5         947   2137    12   150.0          5.5  401         4      2.30
# 6         774   1238    13   134.1          4.0  233         2      1.20
# 7         947   2137    13   150.0          5.5  401         4      2.30
# 8          99   1315    14   118.5          4.0  233         2      1.30
# 9        1103   2580    15   145.0          5.1  432         4      2.50
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9
# 5          16.0  2.000    16.00        8.0     2500        9.5
# 6           8.0  1.000     2.00        0.0     1560       11.7
# 7          16.0  2.000    16.00        8.0     2500        9.5
# 8           4.0  0.512     3.15        0.0     1400       11.0
# 9          16.0  2.000    16.00        2.0     2800        8.1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Product_id'].plot(kind='hist', bins=20, title='Product_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Sale'].plot(kind='hist', bins=20, title='Sale')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['weight'].plot(kind='hist', bins=20, title='weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Product_id', y='Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Price', y='Sale', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Sale', y='weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='weight', y='resoloution', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Sale']
#   ys = series['Product_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Sale', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Sale')
# _ = plt.ylabel('Product_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Sale']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Sale', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Sale')
# _ = plt.ylabel('Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Sale']
#   ys = series['weight']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Sale', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Sale')
# _ = plt.ylabel('weight')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Sale']
#   ys = series['resoloution']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Sale', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Sale')
# _ = plt.ylabel('resoloution')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['Product_id'].plot(kind='line', figsize=(8, 4), title='Product_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Price'].plot(kind='line', figsize=(8, 4), title='Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Sale'].plot(kind='line', figsize=(8, 4), title='Sale')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['weight'].plot(kind='line', figsize=(8, 4), title='weight')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['Price'].plot(kind='hist', bins=20, title='Price')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Key observations from step 1:
#
#
#
# *   The price of a mobile device is influenced by several factors, including its resolution, brand, dimensions, weight, camera quality, RAM capacity, battery life, and CPU performance.
# *   There are 14 attributes in the data set;
#   *   Produt_id: ID of each cellphone
#   *   Price: Price of each cellphone
#   *   Sale: sales number
#   *   Weight: weight of each cellphone
#   *   Resolution: Resolution of each cellphone
#   *   ppi: Phone Pixel Density
#   *   cpu core: Type of CPU core in each cellphone
#   *   cpu frequency: CPU Frequency in each cellphone
#   *   Internal memory: Internal memory of each cellphone
#   *   ram: RAM capacity of each cellphone
#   *   RearCam: Rear Camera quality of each cell phone
#   *   Front_Cam: Front Camera quality of each cell phone
#   *   battery: Life of cellphone battery
#   *   Thickness: Thickness of the cellphone

# %% [markdown]
# # STEP 2: Problem Statment Definition
#
#
# *   Creating a prediction model to forecast the price of mobile phones based on various attributes consistent with all mobile phones.
# *   In order to do so, the data patterns must be analyzed to uncover the key factors influence to the mobile pricing to obtain a thorough comprehension of the dynamics of the market.

# %% [markdown]
# # STEP 3: Target Variable Identification
#
# *   Target Varible: "Price"
# *   Predictors/Features: Sale, Weight, Resolution, PPI(Pixels Per Inch), CPU Core, CPU Frequency, Internal memory, RAM, Rear camera quality, Front camera quality, battery capacity, and phone thickness.
# *   To choose which ML/AI algorithm for the data analysis is appropriate, Based on the problem statement, we need to create a supervised ML Regression model, as the target variable is **Continuous**

# %% [markdown]
# # STEP 4: Visualising the distribution of Target variable

# %%
# %matplotlib inline
# Creating histogram as the Target variable is Continuous
# This will help us to understand the distribution of the PRICE values
CellphoneData['Price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # STEP 5: Basic Level Data Exploration (EDA)

# %%
# Examining example rows within the dataset.
CellphoneData.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
# Inspecting sample rows within the dataset.
CellphoneData.tail()
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem  ram  RearCam  Front_Cam  battery  thickness
# 156         128.0  6.0     12.0       16.0     4080        8.4
# 157         128.0  6.0     20.0        8.0     3400        7.9
# 158          64.0  4.0     20.0       20.0     3000        6.8
# 159         128.0  6.0     20.0        8.0     3400        7.9
# 160          16.0  3.0     21.5       16.0     2700        8.4

# %%
# Observing the summarized information of data
# Data types, Missing values based on number of non-null values Vs total rows etc.
# Remove those variables from data which have too many missing values (Missing Values > 30%)
# Remove Qualitative variables which cannot be used in Machine Learning
CellphoneData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %% [markdown]
# By using the info() method, i discovered that the dataset provides 161 entries across 14 columns, with 0 missing values.

# %%
# Looking at the descriptive statistics of the data
CellphoneData.describe(include='all')
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# min    121.000000    0.000000    0.000000      0.000000    0.000000
# 25%    233.000000    4.000000    1.200000      8.000000    1.000000
# 50%    294.000000    4.000000    1.400000     16.000000    2.000000
# 75%    428.000000    8.000000    1.875000     32.000000    3.000000
# max    806.000000    8.000000    2.700000    128.000000    6.000000
#
#           RearCam   Front_Cam      battery   thickness
# count  161.000000  161.000000   161.000000  161.000000
# mean    10.378261    4.503106  2842.111801    8.921739
# std      6.181585    4.342053  1366.990838    2.192564
# min      0.000000    0.000000   800.000000    5.100000
# 25%      5.000000    0.000000  2040.000000    7.600000
# 50%     12.000000    5.000000  2800.000000    8.400000
# 75%     16.000000    8.000000  3240.000000    9.800000
# max     23.000000   20.000000  9500.000000   18.500000

# %%
# Finging unique values for each column
# TO understand which column is categorical and which one is Continuous
# Typically if the numer of unique values are < 20 then the variable is likely to be a category otherwise continuous
CellphoneData.nunique()
# Out:
# Product_id       83
# Price            81
# Sale            125
# weight           62
# resoloution      24
# ppi              45
# cpu core          6
# cpu freq         28
# internal mem     10
# ram              12
# RearCam          18
# Front_Cam        15
# battery          55
# thickness        49
# dtype: int64

# %% [markdown]
# ## Observations from Step 5:
#
#
#
# *   In Step 5, I explored the dataset using both automated and manual techniques.
# *   Observing sample rows at the start and finish made it easier for me to identify anomalies.
#
# *   Product ID - Qualitative. Not selected.
# *   Price - Contiuous. Selected (Target Variable)
# *   Sale - Contiuous. Selected.
# *   Weight - Contiuous. Selected.
# *   Resolution - Contiuous. Selected.
# *   PPI - Contiuous. Selected.
# *   CPU Core - Categorical. Selected.
# *   CPU Freq - Contiuous. Selected.
# *   Internal Mem - Categorical. Selected.
# *   RAM - Categorical. Selected.
# *   Rear Cam - Contiuous. Selected.
# *   Front Cam - Contiuous. Selected.
# *   Battery - Contiuous. Selected.
# *   Thickness - Contiuous. Selected.

# %% [markdown]
# # STEP 6: Identifying and Rejecting useless columns
#
# *   Through analysis of step 5, Product ID is a qualitative data which does not have influence on cellphone price or sales. Therefore, this collumn is a useless column and have been rejected(removed).

# %% [markdown]
# # STEP 7 (Part A): Visual Explatory Data Analysis of data - Using Bar Charts
#
# For this step, i will am using the categorical elements: CPU CORE, INTERNAL MEM, & RAM.

# %%
# Plotting multiple bar charts at once for categorical variables
# Since there is no default function which can plot bar charts for multiple columns at once
# we are defining our own function for the same

def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline

    import matplotlib.pyplot as plt

    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(20,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
#####################################################################
# Calling the function PlotBarCharts() we have created
PlotBarCharts(inpData=CellphoneData, colsToPlot=['cpu core','internal mem','ram'])

# %% [markdown]
# ## Observations from Step 7 (Part A):
#
# *   The 3 Categorical elements discovered have had their respective data displayed as Bar Charts, utilizing the X-axis to display the Elements name, and the Y-axis to display the data values.
# *   "CPU CORE" has a skewed distribution as only two category values predominate in frequency. This means that creating machine learning models or establishing correlations with the target variable may be difficult with such distributions.
# *   The best data for machine learning regression algorithms to learn from is a balanced distribution of frequencies across categories in an ideal bar chart.

# %% [markdown]
# # STEP 7 (Part B): Visual Explatory Data Analysis of data - Using Histograms
#
# For this step I am using the continuous preditor variables: Sale, Weight, Resolution, PPI, CPU Frequency, Rear Cam, Front Cam, Battery, & Thickness. Price is not included as it is the target variable.

# %%
# Plotting histograms of multiple columns together
CellphoneData.hist(['Sale','weight','resoloution','ppi','cpu freq','RearCam','Front_Cam',
                    'battery','thickness'], figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'Sale'}>,
#         <Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'resoloution'}>],
#        [<Axes: title={'center': 'ppi'}>,
#         <Axes: title={'center': 'cpu freq'}>,
#         <Axes: title={'center': 'RearCam'}>],
#        [<Axes: title={'center': 'Front_Cam'}>,
#         <Axes: title={'center': 'battery'}>,
#         <Axes: title={'center': 'thickness'}>]], dtype=object)

# %% [markdown]
# ## Observations from step 7 (Part B):
#
# *   The 9 continuous varibales selected have had their respective data displayed as histogram Charts, utilizing the X-axis to display the range of values and the y-axis to display the number of values in that range.
# *   A good outcome for histogram is a bell curve or slightly skewed bell curve.
# *   Sale: Selected. Outliers seen beyond 8000, need to treat them.
# *   The distribution of all other selected continuous variables are good.

# %% [markdown]
# # STEP 8: Outlier Analysis

# %%
#Replacing outliers for 'Sale'
# Finding nearest values to 10,000 mark
CellphoneData['Sale'][CellphoneData['Sale']<10000].sort_values(ascending=False)
# Out:
# 160    9807
# 159    8946
# 158    8809
# 157    8016
# 156    4638
#        ...
# 4        11
# 3        11
# 2        10
# 1        10
# 0        10
# Name: Sale, Length: 161, dtype: int64

# %%
# Replacing outliers with nearest possibe value
# Suptrackting value to clear outliers
CellphoneData['Sale'][CellphoneData['Sale']>6000] = 4638

# %% [markdown]
# # STEP 9: Visualising Data Distribution after outlier removal

# %%
CellphoneData.hist(['Sale'], figsize=(18,5))
# Out:
# array([[<Axes: title={'center': 'Sale'}>]], dtype=object)

# %% [markdown]
# ## Observation from step 11
#
# *   Following outlier treatment, the distribution has notably improved.
# *   While a tail remains, it is considerably thick, indicating a substantial number of values within that range, rendering it acceptable.

# %% [markdown]
# # STEP 10: Missing Values Analysis

# %%
# Finding how many missing values are there for each column
CellphoneData.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %% [markdown]
# ## Observation from Step 10:
#
# *   This code proves the earlier discovered that that within the 161 entries across 14 columns of data provided, there are 0 missing values. Therefore it is not necessary to remove any further sample rows.

# %% [markdown]
# # STEP 11: Feature Selection (Attribute Selection)
#
# Given the Target variable is continuous, the appropriate feature selection based on the data distribution consists of:
# *   Continuous Target Variable Vs Continuous Predictor
# * Continuous Target Variable Vs Categorical Predictor

# %% [markdown]
# ### Relationship Exploration: Continuous Target Variable Vs Continuous Predictor - Using scatter charts:

# %%
ContinuousCols=['Sale','weight','resoloution','ppi','cpu freq',
                'RearCam','Front_Cam','battery','thickness']

# Plotting scatter chart for each predictor vs the target variable
for predictor in ContinuousCols:
    CellphoneData.plot.scatter(x=predictor, y='Price', figsize=(10,5), title=predictor+" VS "+ 'Sale')

# %% [markdown]
# ## Observation from Step 11: scatter report

# %% [markdown]
# # STEP 12: Statistical Feature Selection (Continuous Vs Continuous) using Correlation value

# %%
# Calculating correlation matrix
ContinuousCols=['Price','Sale','weight','resoloution','ppi','cpu freq',
                'RearCam','Front_Cam','battery','thickness']

# Creating the correlation matrix
CorrelationData=CellphoneData[ContinuousCols].corr()
CorrelationData
# Out:
#                 Price      Sale    weight  resoloution       ppi  cpu freq  \
# Price        1.000000  0.302110  0.144555     0.404010  0.817614  0.727383
# Sale         0.302110  1.000000  0.019297    -0.004470  0.265335  0.082790
# weight       0.144555  0.019297  1.000000     0.890416 -0.054683  0.222730
# resoloution  0.404010 -0.004470  0.890416     1.000000  0.181292  0.505454
# ppi          0.817614  0.265335 -0.054683     0.181292  1.000000  0.713168
# cpu freq     0.727383  0.082790  0.222730     0.505454  0.713168  1.000000
# RearCam      0.739538  0.270029 -0.029448     0.249892  0.774008  0.625104
# Front_Cam    0.675286  0.445173 -0.005971     0.202720  0.491371  0.358319
# battery      0.559946  0.161846  0.833783     0.843462  0.302517  0.473137
# thickness   -0.716773 -0.018355 -0.185262    -0.533708 -0.496791 -0.614458
#
#               RearCam  Front_Cam   battery  thickness
# Price        0.739538   0.675286  0.559946  -0.716773
# Sale         0.270029   0.445173  0.161846  -0.018355
# weight      -0.029448  -0.005971  0.833783  -0.185262
# resoloution  0.249892   0.202720  0.843462  -0.533708
# ppi          0.774008   0.491371  0.302517  -0.496791
# cpu freq     0.625104   0.358319  0.473137  -0.614458
# RearCam      1.000000   0.596374  0.287821  -0.550998
# Front_Cam    0.596374   1.000000  0.295283  -0.493542
# battery      0.287821   0.295283  1.000000  -0.412682
# thickness   -0.550998  -0.493542 -0.412682   1.000000

# %%
# Filtering only those columns where absolute correlation > 0.5 with Target Variable
# reduce the 0.5 threshold if no variable is selected
CorrelationData['Price'][abs(CorrelationData['Price']) > 0.5 ]
# Out:
# Price        1.000000
# ppi          0.817614
# cpu freq     0.727383
# RearCam      0.739538
# Front_Cam    0.675286
# battery      0.559946
# thickness   -0.716773
# Name: Price, dtype: float64

# %% [markdown]
# ### Observations from Step 12:
#
# *   **'ppi', 'cpu freq', 'RearCam', 'Front_Cam', 'battery', 'thickness**
# *   To identify columns with an absolute correlation with the price variable of more than 0.5, filtering has been used.

# %% [markdown]
# # STEP 13: Relationship exploration: Categorical Vs Continuous -- Box Plots

# %%
# Box plots for continuous Target Variable "MEDV" and Categorical predictors
CategoricalColsList=['cpu core','internal mem','ram']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=1, ncols=len(CategoricalColsList), figsize=(18,5))

# Creating box plots for each continuous predictor against the Target Variable "MEDV"
for PredictorCol , i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    CellphoneData.boxplot(column='Price', by=PredictorCol, figsize=(5,5), vert=True, ax=PlotCanvas[i])

# %% [markdown]
# ### Observations from step 13:
#
# *
# *

# %% [markdown]
# # STEP 14: Statistical Feature Selection (Categorical Vs Continuous) using ANOVA test

# %%
# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]

    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)

        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])

    return(SelectedPredictors)

# %%
#Calling the function to check which categorical variables are correlated with target
CategoricalPredictorList=['cpu core','internal mem','ram']
FunctionAnova(inpData=CellphoneData,
              TargetVariable='Price',
              CategoricalPredictorList=CategoricalPredictorList)
# Out:
# ##### ANOVA Results #####
#
# cpu core is correlated with Price | P-Value: 3.721669566887769e-25
# internal mem is correlated with Price | P-Value: 5.612710293590637e-57
# ram is correlated with Price | P-Value: 1.5941027123567347e-60
# ['cpu core', 'internal mem', 'ram']

# %% [markdown]
# ### Observations from Step 14:
#
# *
# *

# %% [markdown]
# ## Selecting final Predictors/Features for building Machine Learning/AI model.

# %%
SelectedColumns=['cpu core','internal mem','ram','ppi','cpu freq','RearCam',
                 'Front_Cam','battery','thickness']

# Selecting final columns
DataForML=CellphoneData[SelectedColumns]
DataForML.head()
# Out:
#    cpu core  internal mem    ram  ppi  cpu freq  RearCam  Front_Cam  battery  \
# 0         8          16.0  3.000  424      1.35    13.00        8.0     2610
# 1         2           4.0  1.000  233      1.30     3.15        0.0     1700
# 2         4           8.0  1.500  312      1.20    13.00        5.0     2000
# 3         2           4.0  0.512  233      1.30     3.15        0.0     1400
# 4         2           4.0  1.000  233      1.30     3.15        0.0     1700
#
#    thickness
# 0        7.4
# 1        9.9
# 2        7.6
# 3       11.0
# 4        9.9

# %%
# Saving this final data subset for reference during deployment
DataForML.to_pickle('DataForML.pkl')

# %% [markdown]
# # STEP 15: Data conversion to numeric values for machine learning/predictive analysis

# %%
# Treating all the nominal variables at once using dummy variables
DataForML_Numeric=pd.get_dummies(DataForML)

# Adding Target Variable to the data
DataForML_Numeric['Price']=CellphoneData['Price']

# Printing sample rows
DataForML_Numeric.head()
# Out:
#    cpu core  internal mem    ram  ppi  cpu freq  RearCam  Front_Cam  battery  \
# 0         8          16.0  3.000  424      1.35    13.00        8.0     2610
# 1         2           4.0  1.000  233      1.30     3.15        0.0     1700
# 2         4           8.0  1.500  312      1.20    13.00        5.0     2000
# 3         2           4.0  0.512  233      1.30     3.15        0.0     1400
# 4         2           4.0  1.000  233      1.30     3.15        0.0     1700
#
#    thickness  Price
# 0        7.4   2357
# 1        9.9   1749
# 2        7.6   1916
# 3       11.0   1315
# 4        9.9   1749
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['cpu core'].plot(kind='hist', bins=20, title='cpu core')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['internal mem'].plot(kind='hist', bins=20, title='internal mem')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['ram'].plot(kind='hist', bins=20, title='ram')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['ppi'].plot(kind='hist', bins=20, title='ppi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='cpu core', y='internal mem', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='internal mem', y='ram', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='ram', y='ppi', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23.plot(kind='scatter', x='ppi', y='cpu freq', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['cpu core'].plot(kind='line', figsize=(8, 4), title='cpu core')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['internal mem'].plot(kind='line', figsize=(8, 4), title='internal mem')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['ram'].plot(kind='line', figsize=(8, 4), title='ram')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['ppi'].plot(kind='line', figsize=(8, 4), title='ppi')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### Observations for Step 15:
#
# *
# *

# %% [markdown]
# # STEP 16: Machine Learning Model Development

# %%
# Printing all the column names for our reference
DataForML_Numeric.columns
# Out:
# Index(['cpu core', 'internal mem', 'ram', 'ppi', 'cpu freq', 'RearCam',
#        'Front_Cam', 'battery', 'thickness', 'Price'],
#       dtype='object')

# %%
#Separate Target Variable and Predictor Variables
TargetVariable='Price'
Predictors=['cpu core', 'internal mem', 'ram', 'ppi', 'cpu freq', 'RearCam',
       'Front_Cam', 'battery', 'thickness']

X=DataForML_Numeric[Predictors].values
y=DataForML_Numeric[TargetVariable].values

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=428)

# %% [markdown]
# # STEP 17: Standardization/Normalization of data

# %%
### Standardization of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

# Choose between standardization and MinMAx normalization
#PredictorScaler=StandardScaler()
PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)

# Generating the standardized values of X
X=PredictorScalerFit.transform(X)

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Sanity check for the sampled data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (112, 9)
# (112,)
# (49, 9)
# (49,)

# %% [markdown]
# # STEP 18: Multiple Linear Regression Algorithm For ML/AI model building

# %% [markdown]
# ## In steps 18 & 19, i will be running numerous regressors and methods that will be analysed in order to figure which has provides the most accurate results.

# %%
#Multiple Linear Regression
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

# Printing all the parameters of Linear regression
print(RegModel)

# Creating the model on Training Data
LREG=RegModel.fit(X_train,y_train)
prediction=LREG.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# LinearRegression()
# R2 Value: 0.9438465388327321
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833           852.0
# 1  0.160920   0.253731   1676          1867.0
# 2  0.264368   0.164179   2508          2539.0
# 3  0.166667   0.305970   1777          1540.0
# 4  0.118391   0.305970   1511          1600.0
# Mean Accuracy on test data: 94.17768796854146
# Median Accuracy on test data: 94.69264360094054
#
# Accuracy values for 10-fold Cross Validation:
#  [91.69870883 89.64244898 92.37693142 93.33163234 92.42297403 93.92544599
#  94.104439   89.92286794 92.13839328 91.13820067]
#
# Final Average Accuracy of the model: 92.07

# %% [markdown]
# ## Decision Tree:

# %%
# Decision Trees (Multiple if-else statements!)
from sklearn.tree import DecisionTreeRegressor
RegModel = DecisionTreeRegressor(max_depth=5,criterion='friedman_mse')
# Good Range of Max_depth = 2 to 20

# Printing all the parameters of Decision Tree
print(RegModel)

# Creating the model on Training Data
DT=RegModel.fit(X_train,y_train)
prediction=DT.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, DT.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(DT.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=5)
# R2 Value: 0.9788582750890055
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833           754.0
# 1  0.160920   0.253731   1676          1685.0
# 2  0.264368   0.164179   2508          2550.0
# 3  0.166667   0.305970   1777          1685.0
# 4  0.118391   0.305970   1511          1685.0
# Mean Accuracy on test data: 92.44572762164499
# Median Accuracy on test data: 95.20643806857943
#
# Accuracy values for 10-fold Cross Validation:
#  [87.56158784 92.52780236 91.9619367  88.54716437 92.93294336 92.29388784
#  88.4903212  83.07819051 86.06221969 86.69772065]
#
# Final Average Accuracy of the model: 89.02

# %% [markdown]
# ## Plotting/Visualising the Decision Tree:

# %%
# Load libraries
from IPython.display import Image
from sklearn import tree
import pydotplus

# Create DOT data
dot_data = tree.export_graphviz(RegModel, out_file=None,
                                feature_names=Predictors, class_names=TargetVariable)

# printing the rules
#print(dot_data)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# Show graph
Image(graph.create_png(), width=1500,height=200)
# Double click on the graph to zoom in

# %% [markdown]
# ## Randon Forest:

# %%
# Random Forest (Bagging of multiple Decision Trees)
from sklearn.ensemble import RandomForestRegressor
RegModel = RandomForestRegressor(max_depth=4, n_estimators=400,criterion='friedman_mse')
# Good range for max_depth: 2-10 and n_estimators: 100-1000

# Printing all the parameters of Random Forest
print(RegModel)

# Creating the model on Training Data
RF=RegModel.fit(X_train,y_train)
prediction=RF.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, RF.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(RF.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)


# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# RandomForestRegressor(criterion='friedman_mse', max_depth=4, n_estimators=400)
# R2 Value: 0.9709940067481875
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833           846.0
# 1  0.160920   0.253731   1676          1819.0
# 2  0.264368   0.164179   2508          2570.0
# 3  0.166667   0.305970   1777          1667.0
# 4  0.118391   0.305970   1511          1636.0
# Mean Accuracy on test data: 93.70355108313372
# Median Accuracy on test data: 94.48094612352168
#
# Accuracy values for 10-fold Cross Validation:
#  [89.75276979 91.90954304 88.98850325 89.43192266 92.46057228 92.97028247
#  92.36451267 92.32469642 89.30352036 88.2828635 ]
#
# Final Average Accuracy of the model: 90.78

# %% [markdown]
# ## Plotting One of the Decision Tree in Random Forest Regressor:

# %%
# Plotting a single Decision Tree from Random Forest
# Load libraries
from IPython.display import Image
from sklearn import tree
import pydotplus

# Create DOT data for the 6th Decision Tree in Random Forest
dot_data = tree.export_graphviz(RegModel.estimators_[5] , out_file=None,
                                feature_names=Predictors, class_names=TargetVariable)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# Show graph
Image(graph.create_png(), width=1500,height=200)
# Double click on the graph to zoom in

# %% [markdown]
# # STEP 19: AdaBoost Algorithm For ML/AI model building

# %%
# Adaboost (Boosting of multiple Decision Trees)
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Choosing Decision Tree with 6 level as the weak learner
DTR=DecisionTreeRegressor(max_depth=3)
RegModel = AdaBoostRegressor(n_estimators=100, base_estimator=DTR ,learning_rate=0.04)

# Printing all the parameters of Adaboost
print(RegModel)

# Creating the model on Training Data
AB=RegModel.fit(X_train,y_train)
prediction=AB.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, AB.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(AB.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)


# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=3),
#                   learning_rate=0.04, n_estimators=100)
# R2 Value: 0.9545297099511074
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833           754.0
# 1  0.160920   0.253731   1676          1803.0
# 2  0.264368   0.164179   2508          2551.0
# 3  0.166667   0.305970   1777          1658.0
# 4  0.118391   0.305970   1511          1641.0
# Mean Accuracy on test data: 92.51263335223672
# Median Accuracy on test data: 93.30332020258864
#
# Accuracy values for 10-fold Cross Validation:
#  [89.61834222 89.99117887 88.54860316 90.63534745 92.26434631 90.7994462
#  91.19055988 92.11321539 86.26427704 87.92320921]
#
# Final Average Accuracy of the model: 89.93

# %% [markdown]
# ## XGBoost Regressor:

# %%
# Xtreme Gradient Boosting (XGBoost)
from xgboost import XGBRegressor
RegModel=XGBRegressor(max_depth=2,
                      learning_rate=0.1,
                      n_estimators=1000,
                      objective='reg:linear',
                      booster='gbtree')

# Printing all the parameters of XGBoost
print(RegModel)

# Creating the model on Training Data
XGB=RegModel.fit(X_train,y_train)
prediction=XGB.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, XGB.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(XGB.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')
###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])


MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)


# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, objective='reg:linear', ...)
# R2 Value: 0.9999816267041463
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833           744.0
# 1  0.160920   0.253731   1676          1686.0
# 2  0.264368   0.164179   2508          2323.0
# 3  0.166667   0.305970   1777          1774.0
# 4  0.118391   0.305970   1511          1517.0
# Mean Accuracy on test data: 97.55660432647949
# Median Accuracy on test data: 99.62018448182312
#
# Accuracy values for 10-fold Cross Validation:
#  [93.01381341 95.56400386 92.09519187 90.98856361 95.54165535 94.23041695
#  92.34148591 91.50091694 91.90735939 88.93820365]
#
# Final Average Accuracy of the model: 92.61

# %% [markdown]
# ### Plotting a single Decision tree out of XGBoost:

# %%
#Plotting a single Decision tree out of XGBoost
from xgboost import plot_tree
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(20, 8))
plot_tree(XGB, num_trees=10, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## K-Nearest Neighbor(KNN):

# %%
#kNN
# K-Nearest Neighbor(KNN)
from sklearn.neighbors import KNeighborsRegressor
RegModel = KNeighborsRegressor(n_neighbors=3)

# Printing all the parameters of KNN
print(RegModel)

# Creating the model on Training Data
KNN=RegModel.fit(X_train,y_train)
prediction=KNN.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# The variable importance chart is not available for KNN

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# KNeighborsRegressor(n_neighbors=3)
# R2 Value: 0.9650309108713585
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833           707.0
# 1  0.160920   0.253731   1676          1715.0
# 2  0.264368   0.164179   2508          2556.0
# 3  0.166667   0.305970   1777          1710.0
# 4  0.118391   0.305970   1511          1710.0
# Mean Accuracy on test data: 92.42541792282941
# Median Accuracy on test data: 92.89617486338798
#
# Accuracy values for 10-fold Cross Validation:
#  [90.06660789 91.22887764 89.69774996 88.30442731 91.25100589 90.99119027
#  92.37396717 86.20377093 90.36294274 90.14989137]
#
# Final Average Accuracy of the model: 90.06

# %% [markdown]
# ### Support Vector Machine (SVM) Regressor:

# %%
# Support Vector Machines(SVM)
from sklearn import svm
RegModel = svm.SVR(C=50, kernel='rbf', gamma=0.01)

# Printing all the parameters
print(RegModel)

# Creating the model on Training Data
SVM=RegModel.fit(X_train,y_train)
prediction=SVM.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, SVM.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# The built in attribute SVM.coef_ works only for linear kernel
# %matplotlib inline
#feature_importances = pd.Series(SVM.coef_[0], index=Predictors)
#feature_importances.nlargest(10).plot(kind='barh')

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# SVR(C=50, gamma=0.01)
# R2 Value: 0.06376459847494964
#
# ##### Model Validation and Accuracy Calculations ##########
#    cpu core  internal mem       ram       ppi  cpu freq   RearCam  Front_Cam  \
# 0       0.0       0.00000  0.001333  0.065693  0.000000  0.000000      0.000
# 1       0.5       0.12500  0.166667  0.252555  0.444444  0.434783      0.045
# 2       0.5       0.12500  0.500000  0.442336  0.925926  0.900000      0.110
# 3       0.5       0.03125  0.085333  0.083212  0.481481  0.217391      0.000
# 4       0.5       0.06250  0.085333  0.145985  0.444444  0.217391      0.000
#
#     battery  thickness  Price  PredictedPrice
# 0  0.034483   0.582090    833          2211.0
# 1  0.160920   0.253731   1676          2250.0
# 2  0.264368   0.164179   2508          2280.0
# 3  0.166667   0.305970   1777          2239.0
# 4  0.118391   0.305970   1511          2240.0
# Mean Accuracy on test data: 68.33759866244756
# Median Accuracy on test data: 82.15031315240084
#
# Accuracy values for 10-fold Cross Validation:
#  [75.9470639  73.02617387 79.73390921 74.26269267 81.11246179 44.4263733
#  47.3525844  46.43863167 54.97543578 43.34918724]
#
# Final Average Accuracy of the model: 62.06

# %% [markdown]
# # STEP 20: Model Deployment
#
# ## Upon analysisng the data from the previous 2 steps, it is evident that "ram", "ppi", & "internal mem" are consistently top of the variable importance chart in each algorithm.
#
# ## The XGBoost Regression proved to be the most accurate, with an impressive:
#
# *   Mean Accuracy on test data: 97.55660432647949
# *   Median Accuracy on test data: 99.62018448182312

# %%
# Separate Target Variable and Predictor Variables
TargetVariable='Price'

# Selecting the final set of predictors for the deployment
# Based on the variable importance charts of multiple algorithms above
Predictors=['internal mem','ram','ppi']

X=DataForML_Numeric[Predictors].values
y=DataForML_Numeric[TargetVariable].values

### Sandardization of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

# Choose between standardization and MinMAx normalization
#PredictorScaler=StandardScaler()
PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)

# Generating the standardized values of X
X=PredictorScalerFit.transform(X)

print(X.shape)
print(y.shape)
# Out:
# (161, 3)
# (161,)

# %% [markdown]
# ### Cross validating the final model accuracy with less predictors:

# %%
# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# choose from different tunable hyper parameters
from xgboost import XGBRegressor
RegModel=XGBRegressor(max_depth=2,
                      learning_rate=0.1,
                      n_estimators=1000,
                      objective='reg:linear',
                      booster='gbtree')

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [89.7074133  93.94981995 95.02247264 94.30558533 91.20080897 85.23986431
#  88.15017589 91.49234912 89.21230239 88.91286871]
#
# Final Average Accuracy of the model: 90.72

# %% [markdown]
# ### Retraining the final model using 100% data:

# %%
# Training the model on 100% Data available
Final_XGB_Model=RegModel.fit(X,y)

# %% [markdown]
# ### Saving the model:

# %%
import pickle
import os

# Saving the Python objects as serialized files can be done using pickle library
# Here let us save the Final model
with open('Final_XGB_Model.pkl', 'wb') as fileWriteStream:
    pickle.dump(Final_XGB_Model, fileWriteStream)
    # Don't forget to close the filestream!
    fileWriteStream.close()

print('pickle file of Predictive Model is saved at Location:',os.getcwd())
# Out:
# pickle file of Predictive Model is saved at Location: /content/drive/MyDrive/Capstone_Project_ST1

# %% [markdown]
# # STEP 21: Creating the Pyhton File

# %%
from re import IGNORECASE
# This Function can be called from any from any front end tool/website

def FunctionPredictResult(InputData):
    import pandas as pd
    Num_Inputs=InputData.shape[0]

    # Making sure the input data has same columns as it was used for training the model
    # Also, if standardization/normalization was done, then same must be done for new input

    # Appending the new data with the Training data
    DataForML=pd.read_pickle('DataForML.pkl')
    #InputData=InputData.append(DataForML, ignore_index=True)
    InputData = pd.concat([InputData, DataForML], ignore_index=True)

    # Generating dummy variables for rest of the nominal variables
    InputData=pd.get_dummies(InputData)

    # Maintaining the same order of columns as it was during the model training
    Predictors=['internal mem','ram','ppi']

    # Generating the input values to the model
    X=InputData[Predictors].values[0:Num_Inputs]

    # Generating the standardized values of X since it was done while model training also
    X=PredictorScalerFit.transform(X)

    # Loading the Function from pickle file
    import pickle
    with open('Final_XGB_Model.pkl', 'rb') as fileReadStream:
        PredictionModel=pickle.load(fileReadStream)
        # Don't forget to close the filestream!
        fileReadStream.close()

    # Genrating Predictions
    Prediction=PredictionModel.predict(X)
    PredictionResult=pd.DataFrame(Prediction, columns=['Prediction'])
    return(PredictionResult)

# %% [markdown]
# # STEP 22: Final step - Creating prediciton data

# %%
# Calling the function for some new data
NewSampleData=pd.DataFrame(data=[[16,2,400],[14,1.5,333],[8,9,233]],columns=['internal mem','ram','ppi'])

print(NewSampleData)

# Calling the Function for prediction
FunctionPredictResult(InputData=NewSampleData)
# Out:
#    internal mem  ram  ppi
# 0            16  2.0  400
# 1            14  1.5  333
# 2             8  9.0  233
#     Prediction
# 0  2408.173340
# 1  1960.099609
# 2  2143.680176
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['Prediction'].plot(kind='hist', bins=20, title='Prediction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_29['Prediction'].plot(kind='line', figsize=(8, 4), title='Prediction')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### Prediction Conclusion:
#
# *   The predictions for one or many new cases at a time can be generated using the Function FunctionPredictResult().

# %% [markdown]
# # Deploying a predictive model as an API
# ## Deploying the model with few parameters
# ## Function for predictions API

# %%
# Creating the function which can take inputs and return prediction
def FunctionGeneratePrediction(inp_internal_mem , inp_ram, inp_ppi):

    # Creating a data frame for the model input
    SampleInputData=pd.DataFrame(
     data=[[inp_internal_mem , inp_ram, inp_ppi]],
     columns=['internal mem','ram','ppi'])

    # Calling the function defined above using the input parameters
    Predictions=FunctionPredictResult(InputData= SampleInputData)

    # Returning the predictions
    return(Predictions.to_json())

# Function call
FunctionGeneratePrediction( inp_internal_mem=16,
                           inp_ram=2,
                           inp_ppi=400
                             )
# Out:
# '{"Prediction":{"0":2408.1733398438}}'

# %% [markdown]
# # Web Delpoyment:

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.0.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask) (2.1.5)

# %%
from flask import Flask, request, jsonify
import pickle
import pandas as pd
import numpy

# %%
app = Flask(__name__)

@app.route('/prediction_api', methods=["GET"])
def prediction_api():
    try:
        # Getting the paramters from API call
        internal_mem_value = float(request.args.get('internal mem'))
        ram_value=float(request.args.get('ram'))
        ppi_value=float(request.args.get('ppi'))

        # Calling the funtion to get predictions
        prediction_from_api=FunctionGeneratePrediction(
                                                       inp_internal_mem=internal_mem_value,
                                                       inp_ram=ram_value,
                                                       inp_ppi=ppi_value
                                                )

        return (prediction_from_api)

    except Exception as e:
        return('Something is not right!:'+str(e))

# %%
import os
if __name__ =="__main__":

    # Hosting the API in localhost
    app.run(host='127.0.0.1', port=9000, threaded=True, debug=True, use_reloader=False)
    # Interrupt kernel to stop the API

# %%
'''
Sample URL to call the API
Copy and paste below URL in the web browser
http://127.0.0.1:9000/prediction_api?internal_mem=16&ram=2&ppi=400
'''
# Out:
# '\nSample URL to call the API\nCopy and paste below URL in the web browser\nhttp://127.0.0.1:9000/prediction_api?internal_mem=16&ram=2&ppi=400\n'

# %% [markdown]
# # Desktop App deployment: Tkinter package
#
# ## This code must be run in Python:

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor


class MobilePricePredictionApp:
    def __init__(self, master):
        self.master = master
        self.master.title('Mobile Price Prediction')

        self.data = pd.read_csv('Cellphone.csv')
        self.X = self.data.drop(['Price'], axis=1)
        self.y = self.data['Price'].values
        self.sliders = []

        self.X_train, self.X_test, self.y_train, self.y_test = (
            train_test_split(self.X, self.y, test_size=0.2, random_state=42))

        self.model = XGBRegressor()
        self.model.fit(self.X_train, self.y_train)

        self.create_widgets()

    def create_widgets(self):
        for i, column in enumerate(self.data.columns[:-1]):
            label = tk.Label(self.master, text=column + ': ')
            label.grid(row=i, column=0)
            current_val_label = tk.Label(self.master, text='0.0')
            current_val_label.grid(row=i, column=2)
            slider = ttk.Scale(self.master, from_=self.data[column].min(),
                               to=self.data[column].max(), orient="horizontal",
                               command=lambda val, label=current_val_label: label.config(text=f'{float(val):.2f}'))
            slider.grid(row=i, column=1)
            self.sliders.append((slider, current_val_label))

        predict_button = tk.Button(self.master, text='Predict Mobile Price', command=self.predict_price)
        predict_button.grid(row=len(self.data.columns[:-1]), columnspan=3)

    def predict_price(self):
        inputs = [float(slider.get()) for slider, _ in self.sliders]
        price = self.model.predict([inputs])
        messagebox.showinfo('Predicted Mobile Price', f'The predicted mobile price is ${price[0]:.2f}')


if __name__ == '__main__':
    root = tk.Tk()
    app = MobilePricePredictionApp(root)
    root.mainloop()

# %% [markdown]
# # THE END
#
# # u3238947
